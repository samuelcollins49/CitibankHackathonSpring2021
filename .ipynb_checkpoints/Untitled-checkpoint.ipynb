# %%
import cv2
import os
import matplotlib.pyplot as plt

#digit value
x1, y1 = 550, 120
x2, y2 = 680, 175

#handwritten value
x1hw, y1hw = 10, 150
x2hw, y2hw = 520, 190

def load_images_from_folder(folder):
    images = []
    images_words = []
    images_digits = []
    for file_name in os.listdir(folder):
        img = cv2.resize(cv2.imread(os.path.join(folder,file_name), cv2.IMREAD_GRAYSCALE), (700, 350))
        cropped_img_words = gray_img[y1hw:y2hw, x1hw:x2hw]
        cropped_img_digits = gray_img[y1:y2, x1:x2]
        if img is not None:
            images.append(img)
            images_words.append(cropped_img_words)
            images_digits.append(cropped_img_digits)
    return images, images_words, images_digits

# %%
training, training_words, trainging_digits = load_images_from_folder("images")
validation, validation_words, training_digits = load_images_from_folder("validation")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-27-26de62b9226e> in <module>
# ----> 1 training, training_words, trainging_digits = load_images_from_folder("images")
#       2 validation, validation_words, training_digits = load_images_from_folder("validation")
#
# <ipython-input-26-e1957749f6d3> in load_images_from_folder(folder)
#      17     for file_name in os.listdir(folder):
#      18         img = cv2.resize(cv2.imread(os.path.join(folder,file_name), cv2.IMREAD_GRAYSCALE), (700, 350))
# ---> 19         gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
#      20         cropped_img_words = gray_img[y1hw:y2hw, x1hw:x2hw]
#      21         cropped_img_digits = gray_img[y1:y2, x1:x2]
#
# ...

# %%
plt.imshow(trainging_digits[5])
plt.show()

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.models import model_from_json

# %%
from csv import reader
 
# Load a CSV file
def load_csv(filename):
    file = open(filename, "r")
    lines = reader(file)
    dataset = list(lines)
    return dataset

#load_csv("data.csv")

# %%
import pytesseract
from fuzzywuzzy import fuzz 
from fuzzywuzzy import process 
from num2words import num2words

numb_in_words = num2words(input())
numb_arr = numb_in_words.split(" ")
print(numb_arr)

output_words = pytesseract.image_to_string(training_words[5])
print(output_words)
word_arr = output_words.split(" ")

output_digits = pytesseract.image_to_string(training_digits[5])
print("Digits: " + output_digits)

print(len(word_arr))

total_current = 0
for i in range(len(numb_arr)):
    print(word_arr[i+1] + " " + numb_arr[i])
    total_current += (fuzz.WRatio(word_arr[i+1], numb_arr[i]))
    print ((fuzz.WRatio(word_arr[i+1], numb_arr[i])))
    
total = len(numb_arr) * 100
total_needed = total * .75    

if total_current >= total_needed:
    print("Success!")
# Out:
# 4280000
# ['four', 'million,', 'two', 'hundred', 'and', 'eighty', 'thousand']
#
#
# Pour million two hundlreol and eiahty {housarel
#
# Digits6400
#
# 8
#
#
# Pour four
# 75
# million million,
# 100
# two two
# 100
# hundlreol hundred
# 75
# and and
# 100
# eiahty eighty
# 83
# {housarel
#  thousand
# 62
# Success!
